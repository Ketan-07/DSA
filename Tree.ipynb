# %% [markdown]
# # Operations :-
# ### Insert_element
# ### Display
# ### Depth First Search :-
# * In-order Traversal
# * Pre-order Traversal
# * Post-order Traversal
# ### Breadth First Search :-
# * Level Order
# * Zig-Zag Order
# ### Search the element
# ### Height of a tree

# %%
class Tree:
    def __init__(self,data):
        self.prev = None
        self.data = data
        self.next = None

    def insert_the_element(self,val):
        if self.data:
            if val < self.data:
                if self.prev is None:
                    self.prev = Tree(val)
                else:
                    self.prev.insert_the_element(val)
            elif val > self.data:
                if self.next is None:
                    self.next = Tree(val)
                else:
                    self.next.insert_the_element(val)

    def display(self):
        if self.prev:
            self.prev.display()
        print(self.data,end=" -> ")
        if self.next:
            self.next.display()

    def pre_order_traversal(self,root):
        if root:
            print(root.data,end=" --> ")
            self.pre_order_traversal(root.prev)
            self.pre_order_traversal(root.next)

    def in_order_traversal(self,root):
        if root:
            self.in_order_traversal(root.prev)
            print(root.data,end=" --> ")
            self.in_order_traversal(root.next)

    def post_order_traversal(self,root):
        if root:
            self.post_order_traversal(root.prev)
            self.post_order_traversal(root.next)
            print(root.data,end=" --> ")
    
    def level_order_traversal(self,root):
        if root:
            print(root.data,end=" --> ")
            self.level_order_traversal(root.prev)
            self.level_order_traversal(root.next)

    def search

t1 = Tree(15)
t1.insert_the_element(12)
t1.insert_the_element(20)
t1.insert_the_element(25)
t1.insert_the_element(18)
t1.insert_the_element(14)
t1.insert_the_element(9)
t1.insert_the_element(6)
t1.insert_the_element(10)
t1.display()
print("\nPre Order Traversal")
t1.pre_order_traversal(t1)
print("\nIn Order Traversal")
t1.in_order_traversal(t1)
print("\nPost Order Traversal")
t1.post_order_traversal(t1)
print("\nLevel Order Traversal")
t1.level_order_traversal(t1)
# Out:
# 6 -> 9 -> 10 -> 12 -> 14 -> 15 -> 18 -> 20 -> 25 ->
# Pre Order Traversal
# 15 --> 12 --> 9 --> 6 --> 10 --> 14 --> 20 --> 18 --> 25 -->
# In Order Traversal
# 6 --> 9 --> 10 --> 12 --> 14 --> 15 --> 18 --> 20 --> 25 -->
# Post Order Traversal
# 6 --> 10 --> 9 --> 14 --> 12 --> 18 --> 25 --> 20 --> 15 -->
# Level Order Traversal
# 15 --> 12 --> 9 --> 6 --> 10 --> 6 --> 10 --> 14 --> 9 --> 6 --> 10 --> 6 --> 10 --> 14 --> 20 --> 18 --> 25 --> 18 --> 25 --> 12 --> 9 --> 6 --> 10 --> 6 --> 10 --> 14 --> 9 --> 6 --> 10 --> 6 --> 10 --> 14 --> 20 --> 18 --> 25 --> 18 --> 25 -->
